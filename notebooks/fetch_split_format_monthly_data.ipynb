# %% [markdown]
# # EDA Données changement climatique - LSH (Longues Séries Homogénéisées)
# Séries mensuelles corrigées par homogénéisation statistique pour les paramètres températures minimales (TN), maximales (TX), insolations (IN) ou précipitations (RR).

# %% [markdown]
# Liste des fichier qui vont être étudiés :
# - SH_IN pas de lien pour l'outremer correspond au cumul mensuel des durées d'insolation.
# - SH_RR_Outremer ( cumul mensuel des hauteurs de précipitation en mm et 1/10)
# - SH_TN_Outremer (Moyenne mensuelle de la température minimal )
# - SH_TX_Outremer (Moyenne mensuelle de la température maximal sous abri)

# %%
import io
import os
import pandas as pd
import requests 
import zipfile

# %%
# Read and extract CSV files from a ZIP URL
def extract_csv_to_df(urls):
    response = requests.get(urls)

    # Check if the request was successful
    if response.status_code == 200:
        array_metadata = []
        array_data = []
        
        with zipfile.ZipFile(io.BytesIO(response.content)) as zip_file:
            for filename in zip_file.namelist():
                if filename.endswith('.csv'):

                    print(f"Reading {filename}...")
                    # We read the metadata
                    with zip_file.open(filename) as file:                
                        df_metadata = pd.read_csv(file).head(12)
                    
                    # We read the data
                    with zip_file.open(filename) as file:
                        df_data = pd.read_csv(file, sep=';', skiprows=13)

                        # Get the num_post
                        num_post = df_metadata.iloc[0,0].split('=')[1].strip()
                        
                        # Add a num_post column to trace the origin of the measurements
                        df_data.insert(0, 'num_post', num_post)

                    array_metadata.append(df_metadata)
                    array_data.append(df_data)
                        
        return array_metadata, array_data

# %%
# Format the metadata lines into a structured DataFrame
def format_metadata(df_meta):
    
    noms_colonnes_bigquery = {
        "LATITUDE (°)": "LATITUDE_DEG",
        "LONGITUDE(°)": "LONGITUDE_DEG",
        "ALTITUDE (m)": "ALTITUDE_M",
        "ETAT DU POSTE (fermé avec date de fermeture AAAA-MM-JJ ou ouvert à la date de production du fichier le 13/03/2025)": "ETAT_POSTE",
        "Amplitude minimale détectable de la série": "AMPLITUDE_MIN_DETECTABLE",
        "Période homogénéisée": "PERIODE_HOMOGENISEE",
        "Date(s) de rupture(s) d'homogénéité": "DATE_RUPTURE_HOMOGENEITE",
        "Periode homogénéisée  196501 201312  : Q_HOM": "Q_HOM_196501_201312",
        "Données prolongées si nécessaire jusqu'en 202412 par des donnees mensuelles non homogénéisées : Q_HOM": "Q_HOM_PROLONGEES_202412",
        "Periode homogénéisée  195501 201512  : Q_HOM": "Q_HOM_195501_201512",
        "Periode homogénéisée  196801 201312  : Q_HOM": "Q_HOM_196801_201312",
        "Periode homogénéisée  196401 201712  : Q_HOM": "Q_HOM_196401_201712",
        "Periode homogénéisée  197201 201512  : Q_HOM": "Q_HOM_197201_201512",
        "Periode homogénéisée  196701 201512  : Q_HOM": "Q_HOM_196701_201512",
        "Periode homogénéisée  195701 201512  : Q_HOM": "Q_HOM_195701_201512",
        "Periode homogénéisée  196501 201512  : Q_HOM": "Q_HOM_196501_201512",
        "Periode homogénéisée  197001 201512  : Q_HOM": "Q_HOM_197001_201512",
        "Periode homogénéisée  196901 201512  : Q_HOM": "Q_HOM_196901_201512",
        "Periode homogénéisée  196801 201512  : Q_HOM": "Q_HOM_196801_201512",
        "Periode homogénéisée  196501 202112  : Q_HOM": "Q_HOM_196501_202112"
    }
    
    # Extract the column as a list
    lines = df_meta.iloc[:, 0].tolist()
    data = {}
    
    for line in lines:
        line = line.strip()
        
        # Skip lines not starting with "#"
        if not line.startswith("#"):
            continue
        
        # Remove the "#" at the beginning
        content = line[1:].strip()
        
        # Split into key=value or key:value
        if "=" in content:
            key, value = content.split("=", 1)
        elif ":" in content:
            key, value = content.split(":", 1)

        # Remove extra whitespace
        key = key.strip()
        value = value.strip()

        # Handle special case for keys to ensure the import works correctly on BigQuery
        if key in noms_colonnes_bigquery:
            key = noms_colonnes_bigquery[key]

        data[key] = value
            
    # Convert to DataFrame
    df_meta = pd.DataFrame([data])
    
    print(df_meta)
    return df_meta

# %%
test = "ALTITUDE (m)"

if test.endswith("(m)"):
    test = test[:-3].strip() + "_M"

print(test)
# Out:
# ALTITUDE_M

# %%
# Save the dataframe into a CSV file
def df_to_csv(df, output_file):
    df.to_csv(output_file, index=False)
    print(f"✓ Saved in {output_file}")

# %%
# Stack all the metadata dataframes
def format_stackv_metadata(array_df_metadata):
    frames = []
    for df_meta in array_df_metadata:
        frames.append(format_metadata(df_meta))
    return pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()

# %%
# Fetch the CSVs, split metadata and data, and combine them
def split_and_combine_csv(key, url):
    # Fetch then extract metadata and data
    array_metadata, array_data = extract_csv_to_df(url)
    # Format and stack all the metadata dataframes
    df_metadata = format_stackv_metadata(array_metadata)
    # Stack all the dataframes
    df_combined = pd.concat(array_data, ignore_index=True)
    # Rename the "VALEUR" column to the specified, more meaningful, key
    df_data = df_combined.rename(columns={"VALEUR": key})
    
    return df_metadata, df_data

# %%
# Key = name of the file to be generated
# URL = link to the zip file
urls = {
    "Precipitations": "https://www.data.gouv.fr/api/1/datasets/r/9617eade-a4ae-4fa1-bbe7-88458aff67b2",
    "Max_Temp": "https://www.data.gouv.fr/api/1/datasets/r/69f2f61e-781c-4132-84c1-dee3e0becbbb",
    "Min_Temp": "https://www.data.gouv.fr/api/1/datasets/r/9cfc5c85-3a23-4a2b-99b6-57ae76ce25b4"
}

output_dir = os.path.join("..", "data")
os.makedirs(output_dir, exist_ok=True)

for key, url in urls.items():
    basename = f"{output_dir}/{key.lower()}"
    df_metadata, df_data = split_and_combine_csv(key, url)
    df_to_csv(df_metadata, output_file=f"{basename}_metadata.csv")
    df_to_csv(df_data, output_file=f"{basename}_data.csv")
# Out:
# Reading SH_MRR097105002.csv...
# Reading SH_MRR097107002.csv...
# Reading SH_MRR097108003.csv...
# Reading SH_MRR097111001.csv...
# Reading SH_MRR097115003.csv...
# Reading SH_MRR097117002.csv...
# Reading SH_MRR097118001.csv...
# Reading SH_MRR097124004.csv...
# Reading SH_MRR097128008.csv...
# Reading SH_MRR097209017.csv...
# Reading SH_MRR097304001.csv...
# Reading SH_MRR097305001.csv...
# Reading SH_MRR097409230.csv...
# Reading SH_MRR097410238.csv...
# Reading SH_MRR097411150.csv...
# Reading SH_MRR097418110.csv...
# Reading SH_MRR098715003.csv...
# Reading SH_MRR098718001.csv...
# Reading SH_MRR098722003.csv...
# Reading SH_MRR098722005.csv...
# Reading SH_MRR098723001.csv...
# Reading SH_MRR098723003.csv...
# Reading SH_MRR098723004.csv...
# Reading SH_MRR098731002.csv...
# Reading SH_MRR098738010.csv...
# Reading SH_MRR098747002.csv...
# Reading SH_MRR098747013.csv...
# Reading SH_MRR098748003.csv...
# Reading SH_MRR098748009.csv...
# Reading SH_MRR098757001.csv...
# Reading SH_MRR098822001.csv...
# Reading SH_MRR098832002.csv...
# Reading SH_MRR098832006.csv...
# Reading SH_MRR197101015.csv...
# Reading SH_MRR197103003.csv...
# Reading SH_MRR197110001.csv...
# Reading SH_MRR197118006.csv...
# Reading SH_MRR197122004.csv...
# Reading SH_MRR197128004.csv...
# Reading SH_MRR197207002.csv...
# Reading SH_MRR197210001.csv...
# Reading SH_MRR197210004.csv...
# Reading SH_MRR197211003.csv...
# Reading SH_MRR197213002.csv...
# Reading SH_MRR197218002.csv...
# Reading SH_MRR197222002.csv...
# Reading SH_MRR197224001.csv...
# Reading SH_MRR197228005.csv...
# Reading SH_MRR197302001.csv...
# Reading SH_MRR197303001.csv...
# Reading SH_MRR197304003.csv...
# Reading SH_MRR197307001.csv...
# Reading SH_MRR197310004.csv...
# Reading SH_MRR197312002.csv...
# Reading SH_MRR197313001.csv...
# Reading SH_MRR197409210.csv...
# Reading SH_MRR197409240.csv...
# Reading SH_MRR197410202.csv...
# Reading SH_MRR197411132.csv...
# Reading SH_MRR197411164.csv...
# Reading SH_MRR197418150.csv...
# Reading SH_MRR197420110.csv...
# Reading SH_MRR197420150.csv...
# Reading SH_MRR198715002.csv...
# Reading SH_MRR198736001.csv...
# Reading SH_MRR198747005.csv...
# Reading SH_MRR198747007.csv...
# Reading SH_MRR198748002.csv...
# Reading SH_MRR198752001.csv...
# Reading SH_MRR198752006.csv...
# Reading SH_MRR198802001.csv...
# Reading SH_MRR198803001.csv...
# Reading SH_MRR198804001.csv...
# Reading SH_MRR198807001.csv...
# Reading SH_MRR198808001.csv...
# Reading SH_MRR198810001.csv...
# Reading SH_MRR198810002.csv...
# Reading SH_MRR198811001.csv...
# Reading SH_MRR198812001.csv...
# Reading SH_MRR198813001.csv...
# Reading SH_MRR198814001.csv...
# Reading SH_MRR198814003.csv...
# Reading SH_MRR198815001.csv...
# Reading SH_MRR198817002.csv...
# Reading SH_MRR198818001.csv...
# Reading SH_MRR198821001.csv...
# Reading SH_MRR198821002.csv...
# Reading SH_MRR198821005.csv...
# Reading SH_MRR198823001.csv...
# Reading SH_MRR198824001.csv...
# Reading SH_MRR198826001.csv...
# Reading SH_MRR198827001.csv...
# Reading SH_MRR198829001.csv...
# Reading SH_MRR198830001.csv...
# Reading SH_MRR297208001.csv...
# Reading SH_MRR297209004.csv...
# Reading SH_MRR297213004.csv...
# Reading SH_MRR297222005.csv...
# Reading SH_MRR297228001.csv...
# Reading SH_MRR297231002.csv...
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97105002  BASSE-TERRE GUILLARD       15.996       -61.721         92
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR097105002                     0.12       196501 201612
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196501 201612  : Q_HOM  \
# 0                   197512                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE                     NOM_USUEL LATITUDE_DEG LONGITUDE_DEG  \
# 0  97107002  CAPESTERRE-B-EAU NEUFCHATEAU       16.079         -61.6
#
#   ALTITUDE_M ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0        253     ouvert  MRR097107002                     0.12
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 201612  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196501 201612  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE                   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97108003  CAPESTERRE-M-GALANTE VIDON         15.9       -61.249        146
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2022-12-31  MRR097108003                     0.14
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 202012  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196501 202012  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97111001  DESHAIES GENDARMERIE       16.311       -61.791         42
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR097111001                     0.14       196501 201612
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196501 201612  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE         NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97115003  LAMENTIN BLACHON        16.28       -61.629         16
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2017-07-31  MRR097115003                     0.13
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 201612  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196501 201612  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97117002  LE MOULE MONTPLAISIR       16.297       -61.318         41
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2023-07-31  MRR097117002                     0.12
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 202012  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196501 202012  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE               NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97118001  PETIT-BOURG VERSAILLES       16.226       -61.594         26
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2022-12-31  MRR097118001                     0.12
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 201612            199012 199712
#
#   Periode homogénéisée  196501 201612  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE                  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97124004  ST-CLAUDE GEN BONNE-TERRE       16.022       -61.707        374
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2018-01-15  MRR097124004                     0.15
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       197101 201612  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  197101 201612  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE          NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97128008  STE-ANNE GENTILLY       16.277       -61.363         45
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2023-07-31  MRR097128008                     0.11
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196801 202012  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196801 202012  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE           NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97209017  FORT-FRANCE COLSON       14.694       -61.088        587
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR097209017                     0.09       196201 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0     197612 199212 200712                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97304001  ILE ROYALE        5.283       -52.583         48     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR097304001                     0.11       195501 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195501 201812  : Q_HOM  \
# 0                   198212                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97305001    TONATE        5.015       -52.474          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR097305001                     0.11       195901 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195901 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97409230  LE COLOSSE      -20.935        55.665         16
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2024-02-01  MRR097409230                     0.09
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196101 201712  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196101 201712  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE     NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97410238  SAINT-BENOIT      -21.059        55.719         43     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR097410238                     0.09       196101 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0            198907 200412                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97411150  SAINT-FRANCOIS      -20.921        55.456        545     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR097411150                     0.13       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97418110  GILLOT-AEROPORT      -20.892        55.529          8     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR097418110                     0.12       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98715003    FAAA 3      -17.567      -149.573        338     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098715003                     0.08       196801 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196801 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98718001      OMOA      -10.517      -138.682          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098718001                     0.19       196201 201412
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 201412  : Q_HOM  \
# 0                   200512                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98722003  PAPENOO 1      -17.513      -149.426         41     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098722003                     0.12       196801 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196801 201812  : Q_HOM  \
# 0            197712 200604                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  98722005  TIAREI 2      -17.543      -149.348          5
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2020-07-31  MRR098722005                      0.1
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       197101 201812            198012 198410
#
#   Periode homogénéisée  197101 201812  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98723001   HIVA-OA       -9.806      -139.036         51     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098723001                     0.15       196201 201412
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 201412  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98723003  HANAIAPA       -9.723       -139.01         15     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098723003                     0.13       196201 201412
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 201412  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98723004    PUAMAU       -9.767      -138.876        106     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098723004                     0.15       196201 201412
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 201412  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98731002   HATIHEU       -8.824      -140.076          6     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098731002                     0.17       196201 201412
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 201412  : Q_HOM  \
# 0            196512 197712                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98738010  VAIRAA P1      -17.659      -149.595          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098738010                     0.13       196001 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98747002    PUEU 1      -17.745      -149.212          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098747002                      0.1       196801 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196801 201812  : Q_HOM  \
# 0            197707 200612                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98747013  FAAONE 2      -17.693      -149.305          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098747013                     0.11       196801 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196801 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98748003  TEAHUPOO 2      -17.858      -149.249          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098748003                     0.13       196901 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196901 201812  : Q_HOM  \
# 0                   200606                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98748009  VAIRAO 2      -17.818      -149.295          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098748009                     0.12       197501 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  197501 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  98757001  HAKAHAU 1       -9.365      -140.051         25
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2019-04-30  MRR098757001                     0.18
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196201 201412                   196802
#
#   Periode homogénéisée  196201 201412  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98822001  POINDIMIE      -20.933       165.328         14     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098822001                     0.13       196501 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196501 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98832002  YATE MRIE      -22.157       166.939         25     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098832002                     0.18       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0            198212 200312                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98832006  RIVIERE BLANCHE      -22.133       166.726        171     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR098832006                     0.16       196001 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201712  : Q_HOM  \
# 0                   197512                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97101015  LE RAIZET AERO       16.264       -61.516         11     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197101015                     0.11       196501 202012
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196501 202012  : Q_HOM  \
# 0                   199212                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE           NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97103003  BAIE-MAHAULT DUPUY       16.257       -61.612         22
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2022-07-31  MRR197103003                      0.1
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 201612                   200012
#
#   Periode homogénéisée  196501 201612  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE                NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97110001  LA DESIRADE GENDARMERIE       16.298       -61.096          7
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197110001                     0.15       196501 202012
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196501 202012  : Q_HOM  \
# 0            197812 200801                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE                NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97118006  PETIT-BOURG GENDARMERIE       16.197         -61.6         55
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2020-04-01  MRR197118006                     0.11
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196701 201912                   200412
#
#   Periode homogénéisée  196701 201912  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE               NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97122004  PORT-LOUIS GENDARMERIE       16.422       -61.525         18
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197122004                     0.13       196601 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196601 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97128004  STE-ANNE MARLY       16.285       -61.335         42
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2024-11-14  MRR197128004                     0.12
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196501 202012                   197712
#
#   Periode homogénéisée  196501 202012  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97207002     DUCOS       14.542       -60.977          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197207002                     0.08       196201 202312
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97210001  FRANCOIS-CHOPOT        14.63        -60.92         53     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197210001                     0.09       196201 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0                   199212                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97210004  FRANCOIS-SIMON        14.59       -60.869         13     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197210004                     0.11       196401 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196401 202312  : Q_HOM  \
# 0     196912 197912 200803                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE     NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97211003  GRANDRIVIERE       14.875       -61.181          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197211003                     0.11       196201 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0            200312 201512                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97213002  LAMENTIN-QUARRE       14.633       -60.992         19
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2024-01-01  MRR197213002                     0.08
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196301 202312                   199312
#
#   Periode homogénéisée  196301 202312  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE          NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97218002  MORNE-ROUGE-CHAMP       14.755        -61.11        350
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197218002                     0.08       196201 202312
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97222002  ROBERT-PTE FORT        14.68       -60.926         16     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197222002                      0.1       196201 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0                   199612                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE         NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97224001  ST-JOSEPH RABUCH       14.679       -61.057        380
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197224001                     0.08       196201 202312
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196201 202312  : Q_HOM  \
# 0            197012 200811                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97228005  STE-MARIE  MORN ESSE       14.743       -61.017        218
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2024-03-01  MRR197228005                     0.09
#
#   PERIODE_HOMOGENISEE DATE_RUPTURE_HOMOGENEITE  \
# 0       196201 202312     197412 199212 201012
#
#   Periode homogénéisée  196201 202312  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE      NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97302001  CAYENNE VILLE        4.941       -52.319          4
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2019-09-10  MRR197302001                     0.09
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       195501 201812  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  195501 201812  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97303001  IRACOUBO         5.48       -53.212          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197303001                     0.11       195501 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195501 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97304003  KOUROU CSG        5.209       -52.748         17     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197304003                      0.1       196701 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196701 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97307001  CAYENNE-MATOURY        4.822       -52.365          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197307001                     0.08       195501 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195501 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97310004     ROURA        4.728       -52.325         21     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197310004                     0.08       195601 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195601 201812  : Q_HOM  \
# 0                   199312                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97312002  SINNAMARY        5.374       -52.952          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197312002                      0.1       195501 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195501 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97313001  MONTSINERY        4.891       -52.492          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197313001                     0.08       195901 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195901 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97409210  BOIS-ROUGE      -20.914        55.641          5     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197409210                      0.1       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97409240   MENCIOL      -20.961        55.626        181     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197409240                     0.07       196101 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0            198912 200102                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97410202  BEAUVALLON      -21.008        55.693         16     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197410202                     0.08       196101 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0                   200412                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97411132  CHAUDRON      -20.897        55.495         38     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197411132                     0.12       196701 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196701 201712  : Q_HOM  \
# 0            198812 200112                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE                   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97411164  LE BRULE - VAL FLEURI_SAPC      -20.942         55.43       1069
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197411164                     0.15       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE              NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97418150  BEAUFOND SAINTE-MARIE      -20.927         55.56        225
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2018-12-31  MRR197418150                     0.07
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196101 201712  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196101 201712  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97420110  GRAND-HAZIER - CIRAD      -20.903        55.586         69
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MRR197420110                     0.07       196101 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0                   199212                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97420150  BAGATELLE_SAPC      -20.931        55.577        262     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR197420150                     0.06       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98715002      FAAA      -17.555      -149.614          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198715002                     0.11       196001 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201812  : Q_HOM  \
# 0                   200712                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98736001   PIRAE 1      -17.536      -149.539         34     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198736001                     0.11       196001 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201812  : Q_HOM  \
# 0            198503 199004                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  98747005  AFAAHITI 3      -17.724      -149.316         60
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2021-09-30  MRR198747005                      0.1
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       196001 201812  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  196001 201812  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98747007  AFAAHITI 4      -17.757      -149.272        232     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198747007                     0.09       196101 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201812  : Q_HOM  \
# 0            197903 200406                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98748002  TEAHUPOO 1      -17.847      -149.267          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198748002                     0.14       196001 201812
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201812  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98752001  PAPEARI 1      -17.759      -149.377          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198752001                     0.12       196001 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196001 201812  : Q_HOM  \
# 0     196912 197812 200012                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98752006  PAPEARI 3      -17.741      -149.342         20     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198752006                      0.1       196701 201812
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196701 201812  : Q_HOM  \
# 0                   198612                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98802001  BOULOUPARIS      -21.874       166.052          8     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198802001                     0.15       195601 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195601 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98803001   BOURAIL      -21.555       165.494         25     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198803001                     0.14       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0            196606 197510                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98804001    CANALA      -21.526       165.969         35     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198804001                     0.19       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE       NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98807001  HIENGHENE GEND      -20.688        164.95         22     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198807001                     0.14       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98808001  HOUAILOU P      -21.278       165.628         11     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198808001                     0.16       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98810001     GOMEN      -20.667       164.396         15     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198810001                     0.15       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0                   197612                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98810002     OUACO      -20.837       164.469         11     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198810002                     0.15       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0                   199812                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98811001      KONE      -21.051       164.834          9     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198811001                     0.16       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98812001    KOUMAC      -20.559       164.284         25     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198812001                     0.15       195401 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195401 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98813001    LA FOA      -21.701       165.815         12     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198813001                     0.15       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98814001  OUANAHAM      -20.778       167.241         30     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198814001                     0.14       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98814003  CHEPENEHE      -20.785       167.152         10     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198814003                     0.13       196101 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0                   196512                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98815001  LA ROCHE      -21.482       168.036         41     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198815001                     0.17       196101 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  196101 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  98817002      PLUM      -22.295       166.658          5
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2024-12-31  MRR198817002                     0.16
#
#   PERIODE_HOMOGENISEE      DATE_RUPTURE_HOMOGENEITE  \
# 0       195201 201712  Aucune rupture d'homogénéité
#
#   Periode homogénéisée  195201 201712  : Q_HOM Q_HOM_PROLONGEES_202412
# 0                                            1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98818001    NOUMEA      -22.276       166.453         69     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198818001                     0.14       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98821001  LA TONTOUTA      -22.017       166.222         37     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198821001                     0.14       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0                   198203                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98821002     PAITA      -22.137        166.37         21     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198821002                     0.14       195201 201712
#
#   DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0                   200312                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE      NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98821005  PORT LAGUERRE      -22.105        166.32         23     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198821005                     0.14       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98823001  PONERIHOUEN      -21.072       165.404         27     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MRR198823001                     0.14       195201 201712
#
#        DATE_RUPTURE_HOMOGENEITE Periode homogénéisée  195201 201712  : Q_HOM  \
# 0  Aucune rupture d'homogénéité                                            1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# ...
# Reading SH_MTN198832002.csv...
# Reading SH_MTN297208001.csv...
# Reading SH_MTN297209004.csv...
# Reading SH_MTN297213004.csv...
# Reading SH_MTN297218002.csv...
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97352001  SAUL_SAPC        3.624       -53.208        219     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN097352001                     0.23       195501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_195501_201512 Q_HOM_PROLONGEES_202412
# 0            195712 201212                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97409240   MENCIOL      -20.961        55.626        181     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN097409240                     0.14       196801 201312
#
#              DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312  \
# 0  197912 198306 198912 199212 200102                   1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE             NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97416463  PIERREFONDS-AEROPORT       -21.32        55.426         21
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN097416463                     0.13       196801 201312
#
#              DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312  \
# 0  197407 198902 199901 200412 200912                   1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE              NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97416465  LIGNE-PARADIS - CIRAD      -21.315        55.487        178
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN097416465                     0.11       196801 201312
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312 Q_HOM_PROLONGEES_202412
# 0                   200512                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98715002      FAAA      -17.555      -149.614          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN098715002                     0.16       197201 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_197201_201512 Q_HOM_PROLONGEES_202412
# 0                   199212                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98720002  HAO AERO      -18.063      -140.961          5     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN098720002                     0.18       196401 201712
#
#        DATE_RUPTURE_HOMOGENEITE Q_HOM_196401_201712 Q_HOM_PROLONGEES_202412
# 0  Aucune rupture d'homogénéité                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98749001   TAKAROA      -14.457      -145.025          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN098749001                     0.17       196401 201712
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196401_201712 Q_HOM_PROLONGEES_202412
# 0            197512 201108                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98750003      OPOA      -16.827      -151.373          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN098750003                     0.19       197201 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_197201_201512 Q_HOM_PROLONGEES_202412
# 0     197507 198312 199812                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98809001      MOUE       -22.59       167.452         95     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN098809001                     0.18       197201 201512
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_197201_201512 Q_HOM_PROLONGEES_202412
# 0  198012 198811 199012 200612                   1                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97304003  KOUROU CSG        5.209       -52.748         17     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197304003                     0.15       196701 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196701_201512 Q_HOM_PROLONGEES_202412
# 0            196812 198712                   1                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97307001  CAYENNE-MATOURY        4.822       -52.365          4     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197307001                     0.14       195501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_195501_201512 Q_HOM_PROLONGEES_202412
# 0     196012 198112 199112                   1                       0
#   NUM_POSTE      NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97308001  SAINT GEORGES        3.891       -51.805          6     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197308001                     0.16       195501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_195501_201512 Q_HOM_PROLONGEES_202412
# 0                   195712                   1                       0
#   NUM_POSTE      NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97311001  SAINT LAURENT        5.486       -54.032          5     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197311001                     0.15       195501 201512
#
#              DATE_RUPTURE_HOMOGENEITE Q_HOM_195501_201512  \
# 0  196112 198212 199112 200509 200910                   1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97353001  MARIPASOULA         3.64       -54.028        106     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197353001                     0.14       195501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_195501_201512 Q_HOM_PROLONGEES_202412
# 0            198312 199812                   1                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97413520  COLIMACONS       -21.13        55.305        798     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197413520                     0.13       196801 201312
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312 Q_HOM_PROLONGEES_202412
# 0  198112 198512 198812 199512                   1                       0
#   NUM_POSTE        NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97418110  GILLOT-AEROPORT      -20.892        55.529          8     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN197418110                     0.11       196801 201312
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312 Q_HOM_PROLONGEES_202412
# 0  197012 198008 199112 199408                   1                       0
#   NUM_POSTE          NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97422440  PLAINE DES CAFRES      -21.209        55.573       1560
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN197422440                     0.18       196801 201312
#
#              DATE_RUPTURE_HOMOGENEITE Q_HOM_196801_201312  \
# 0  197412 198210 198702 200112 200912                   1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98803003  NESSADIOU      -21.621        165.48          2     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198803003                     0.16       196701 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196701_201512 Q_HOM_PROLONGEES_202412
# 0     197012 197412 200301                   1                       0
#   NUM_POSTE   NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98808001  HOUAILOU P      -21.278       165.628         11     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198808001                      0.2       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0     198604 198712 199708                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98811001      KONE      -21.051       164.834          9     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198811001                     0.24       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0     198212 199305 200108                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98812001    KOUMAC      -20.559       164.284         25     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198812001                     0.15       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0                   199012                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98813001    LA FOA      -21.701       165.815         12     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198813001                     0.27       196501 201512
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0  196909 197810 198912 200603                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98814001  OUANAHAM      -20.778       167.241         30     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198814001                     0.29       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0            198012 200509                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98815001  LA ROCHE      -21.482       168.036         41     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198815001                     0.29       197201 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_197201_201512 Q_HOM_PROLONGEES_202412
# 0            198209 200512                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98818001    NOUMEA      -22.276       166.453         69     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198818001                     0.16       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0            197606 198012                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98818002   MAGENTA       -22.26       166.474          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198818002                     0.15       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0     196912 198012 199310                   1                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98821001  LA TONTOUTA      -22.017       166.222         37     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198821001                     0.16       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0     196912 198202 198812                   1                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98822001  POINDIMIE      -20.933       165.328         14     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198822001                     0.15       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0     196612 197003 198112                   1                       0
#   NUM_POSTE    NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98823001  PONERIHOUEN      -21.072       165.404         27     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198823001                     0.25       196901 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196901_201512 Q_HOM_PROLONGEES_202412
# 0                   198912                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98827001      POYA      -21.345       165.157          7     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198827001                     0.23       196501 201512
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0            199012 199905                   1                       0
#   NUM_POSTE NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  98829001   THIO P.      -21.611       166.216         10
#
#             ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE  \
# 0  fermé au 2021-06-30  MTN198829001                     0.16
#
#   PERIODE_HOMOGENISEE     DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512  \
# 0       196501 201512  197603 197712 198512 198912                   1
#
#   Q_HOM_PROLONGEES_202412
# 0                       0
#   NUM_POSTE  NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  98832002  YATE MRIE      -22.157       166.939         25     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN198832002                     0.16       196501 201512
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_201512 Q_HOM_PROLONGEES_202412
# 0  196712 197012 198012 199712                   1                       0
#   NUM_POSTE         NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97208001  FOND-DENIS-CADET       14.735       -61.145        493
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN297208001                     0.21       196501 202112
#
#        DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_202112 Q_HOM_PROLONGEES_202412
# 0  Aucune rupture d'homogénéité                   1                       0
#   NUM_POSTE              NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97209004  FORT-DE-FRANCE DESAIX       14.618       -61.064        143
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN297209004                      0.2       196501 202112
#
#       DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_202112 Q_HOM_PROLONGEES_202412
# 0  197112 198412 199012 201012                   1                       0
#   NUM_POSTE      NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M ETAT_POSTE  \
# 0  97213004  LAMENTIN-AERO       14.595       -60.996          3     ouvert
#
#       NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0  MTN297213004                     0.22       196501 202112
#
#        DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_202112 Q_HOM_PROLONGEES_202412
# 0  Aucune rupture d'homogénéité                   1                       0
#   NUM_POSTE          NOM_USUEL LATITUDE_DEG LONGITUDE_DEG ALTITUDE_M  \
# 0  97218002  MORNE-ROUGE-CHAMP       14.755        -61.11        350
#
#   ETAT_POSTE     NUM_SERIE AMPLITUDE_MIN_DETECTABLE PERIODE_HOMOGENISEE  \
# 0     ouvert  MTN297218002                     0.23       196501 202112
#
#   DATE_RUPTURE_HOMOGENEITE Q_HOM_196501_202112 Q_HOM_PROLONGEES_202412
# 0     197112 197612 200612                   1                       0
# ✓ Saved in ../data/min_temp_metadata.csv
# ✓ Saved in ../data/min_temp_data.csv
